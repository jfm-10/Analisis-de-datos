# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score, calinski_harabasz_score
from sklearn.feature_selection import SelectKBest
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Cargar los datos
data = pd.read_csv(r'C:\Users\alejo\OneDrive\Documentos\UNAD\SEMESTRE 4\ANÁLISIS DE DATOS\Tarea 3\Anexo 4 - Dataset Red Wine Quality\Mall_Customers.csv')

# %%
# Análisis exploratorio de datos
print(data.describe().round(2))
sns.pairplot(data)

# %%
# Preprocesamiento de los datos
# Aquí puedes incluir la limpieza de datos, el tratamiento de valores faltantes, etc.
# Este es un ejemplo de cómo podrías tratar los valores faltantes
data = data.dropna()

# %%
if 'Spending Score (1-100)' in data.columns:
    y = data['Spending Score (1-100)']
else:
    # Handle the case when 'Spending Score (1-100)' column is not found
    y = None  # or any other appropriate action

# %%
X_new = None  # Define the variable "X_new" with an appropriate value
kmeans = None  # Define the variable "kmeans" with an appropriate value

if X_new is not None:
    labels = kmeans.fit_predict(X_new)
else:
    labels = None  # or any other appropriate action

# %%
if 'Age' in data.columns and 'Annual Income (k$)' in data.columns:
    X_new = data[['Age', 'Annual Income (k$)']]
else:
    print("One or both of the columns 'Age' and 'Annual Income (k$)' do not exist in the dataframe.")

# %%
X_new = np.array(X_new)  # Convert X_new to a numpy array
label = None  # Define the variable "label" with an appropriate value
plt.scatter(X_new[:, 0], X_new[:, 1], c=label)
